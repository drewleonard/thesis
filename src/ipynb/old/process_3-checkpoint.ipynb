# %%
from datetime import datetime
import pandas as pd
import math
import re

# %%
# Load data into pd.df
path = "~/Documents/thesis/data/csv/FacebookAds.csv"
df = pd.read_csv(path)

# Remove rows with null AdText values
df = df[pd.notnull(df['AdText'])]

# Remove immediately unwanted columns
# Either too unavailable or not useful
df = df.drop(columns=[
    'EndDate', 'Behaviors', 'PeopleWhoMatch', 'Placements', 'pages',
    'FriendsOfConnections', 'ExcludedConnections', 'Gender', 'Generation',
    'Politics', 'CustomAudience', 'SourceFile', 'SourceZip', 'Language'
])

# Remove rows will no CreationDate value
df = df[pd.notnull(df['CreationDate'])]

# Reset index after dropping columns
df = df.reset_index(drop=True)

# %%
# Fix float columns
integer_cols = ['Clicks','Impressions','AdSpend']
for n, e in df.iterrows():
    for col in integer_cols:
        if math.isnan(e[col]):
            df.at[n,col] = 0.0

# %%
# Fid AdText column
for n, e in enumerate(df['AdText']):
    curr_e = re.sub(r'http\S+', '', e)
    curr_e = curr_e.replace('Subscribe to our channel:','')
    curr_e = curr_e.replace('Follow my Facebook:','')
    curr_e = curr_e.replace('Follow me on Instagram:','')
    curr_e = curr_e.replace('Follow me on Twitter:','')
    df.at[n, 'AdText'] = curr_e

# %%
# Fix some string cols
string_cols = ['LandingPage','Location','Interests','AdSpendCurrency']
for string_col in string_cols:
    df[string_col] = df[string_col].astype(str)
    for n, e in enumerate(df[string_col]):
        if e == 'nan':
            df.at[n, string_col] = 'unavailable'

# %%
interest_keywords = {
    'left wing': [
        'humanitarianism', 'i have a dream', 'anti-racism', 'social justice',
        'wellness', 'liberalism', 'malcolm x', 'human rights', 'democratic',
        'mother jones', 'bernie', 'libertarian'
    ],
    'right wing': [
        'veterans', 'secession', 'patriotism', 'republican', 'tea party',
        'southern', 'donald trump', 'vietnam', 'manufacturing', 'god',
        'ron paul', 'breitbart', 'texas', 'fox news', 'jesus', 'confederate',
        'cato institute', 'evangelicalism', 'right-wing', 'nationalism'
    ],
    'self defense': ['self-defense', 'self defense'],
    'illegal immigration': [
        'stop illegal immigration', 'deportation', 'illegal immigration',
        'immigration'
    ],
    'gun': ['2nd amendment', 'gun rights', 'bear arms', 'second amendment'],
    'black': [
        'BlackNews.com', 'black power', 'cop block', 'police brutality',
        'african american', 'african-american', 'black (color)',
        'pan-africanism', 'martin luther king', 'black', 'african', 'trayvon',
        'racial', 'anti-racism','martin luther king','racism in the united states'
    ],
    'islam': ['islam', 'quran', 'muslims', 'muslim'],
    'police': [
        'law enforcement', 'the badge', 'blue line', 'police or safety',
        'police officer or safety'
    ],
    'hispanic': ['hispanic', 'mexican', 'latin', 'chicano', 'la raza'],
    'native american': ['native american', 'american indian'],
    'music': ['music', 'soundcloud', 'apple music', 'itunes', 'spotify','software'],
    'entertainment': [
        'buzzfeed', '9gag', 'entertainment', 'imgur', 'humour', 'funny',
        'reddit', 'games', 'meme'
    ],
    'lgbt': ['lgbt', 'gay', 'transgender', 'trans', 'homosexuality'],
    'Government':
    ['syria', 'army', 'hillary', 'government', 'obama', 'senate', 'tax', 'political party'],
    'prison': ['prison', 'incarceration', 'correctional', 'inmates'],
    'unavailable': ['unavailable']
}

# %%
# Run through interests
interest_map = {}

for n, unique_interest in enumerate(df['Interests'].unique()):
    
    # Put unique interest in lower case
    unique_interest = unique_interest.lower()
    
    # Arr to store found topics
    found_topics = {}
    
    # Iterate over set of topics with interest keywords
    for topic, keywords in interest_keywords.iteritems():
        
        for keyword in keywords:
            if keyword in unique_interest:
                if topic not in found_topics:
                    found_topics[topic] = 0
                found_topics[topic] += 1
                
    else:
        interest_map[unique_interest] = found_topics

# %%
for interest, topics in interest_map.iteritems():
    
    curr = {
        'count': 0,
        'name': ''
    }
    
    for topic_name, topic_count in topics.iteritems():
        if topic_count > curr['count']:
            curr['count'] = topic_count
            curr['name'] = topic_name
    
    if curr['name'] == '':
        curr['name'] = 'mixed'
    
    interest_map[interest] = curr['name']

# %%
df[df.Interests == 'unavailable'].count()
# Out:
# AdID               787
# AdText             787
# Clicks             787
# Impressions        787
# Age                787
# CreationDate       787
# LandingPage        787
# Location           787
# Interests          787
# AdSpend            787
# AdSpendCurrency    787
# dtype: int64

# %%
for n, e in enumerate(df['Interests']):
    df.at[n,'Interests'] = interest_map[e.lower()]

# %%
df.head(100)
# Out:
#     AdID                                             AdText   Clicks  \
# 0    374            Join us because we care. Black matters.      0.0
# 1    655  NOT EVERY BOY WANTS TO BE A SOLDIER. A beautif...     35.0
# 2    664  "People can tolerate two homosexuals they see ...     26.0
# 3     79                      ?????? ??? ????? ? ??????????      0.0
# 4    325  California... knows how to party California......      4.0
# 5    326  Since 2010, over 350 of our lives have been ta...    517.0
# 6    327  'Just like Trayvon Martin, race mattered for A...      7.0
# 7    328  Race war started by Texas teacher A Texas four...     17.0
# 8    329  The image of 1938 shows several African Americ...     18.0
# 9    330  American Racists On The Road        The racist...     24.0
# 10   331          "Free Figure's Black Power Rally at VCU:"     43.0
# 11   332  A woman pretended Afro-American to gain contro...     47.0
# 12   333  2Pac believed in Fight Tupac Shakur was indeed...     47.0
# 13   334  Today we celebrate the legendary rapper who ev...     10.0
# 14   335  It is an American history. African-American ci...     26.0
# 15   336  Americans so much effort to hate each other in...     42.0
# 16   337  No national outrage for an incident at pool pa...     23.0
# 17   338  A 13-year-old child was tasered by cop for ska...     97.0
# 18   339  Only 9 days this year nobody was killed by pol...     55.0
# 19   340  In early 1900s this Black Americana Chocolate ...     21.0
# 20   341  Sadness and shocking tragedy at historically b...    274.0
# 21   342  Rachel Dolezal is wearing the other persons sh...     46.0
# 22   343  The violent pool story #3. White police office...     31.0
# 23   344  What else has to happen for you all to realize...     59.0
# 24   345  Thousands Walk Hand In Hand Across Ravenel Bri...     48.0
# 25   346  Whatever the white man has done. Black America...     65.0
# 26   347  How many of you believe in Black Jesus?       ...     57.0
# 27   348  Black is beautiful. God knows what he is doing...     74.0
# 28   349  A small group of activists burned two confeder...     23.0
# 29   356        Such a beautiful day! Such a beatiful view!      3.0
# ..   ...                                                ...      ...
# 70   429  Sadness and shocking tragedy at historically b...      0.0
# 71   438  Patriotism comes from your heart... follow its...     39.0
# 72   447  We can't all be Presidents, but we can all be ...      0.0
# 73   450  United We Stand! Welcome every patriot we can ...  72043.0
# 74   453  We can't all be Presidents, but we can all be ...      0.0
# 75   481  Patriotism begins at home. Join new community ...      0.0
# 76   484  Patriotism comes from your heart... follow its...      0.0
# 77   504  Patriotism begins at home. Join new community ...      0.0
# 78   505                    Your freedom starts here. Join!     59.0
# 79   520                    Your freedom starts here. Join!      0.0
# 80   551  Republican strategist Karl Rove said on "Fox N...      0.0
# 81   552  The Chinese hackers executed a complex attack ...      0.0
# 82   553  The Battle of Okinawa, codenamed Operation Ice...      0.0
# 83   554  Since the game of American football was first ...      0.0
# 84   555  It is a symbol of patriots who were willing to...      0.0
# 85   556  Why do immigrants think that the U.S. governme...      0.0
# 86   557  Our flag is one with colors every so bright A ...      0.0
# 87   580  We speak for all fellow members of LGBT commun...    103.0
# 88   581  We speak for all fellow members of LGBT commun...     36.0
# 89   582  We speak for all fellow members of LGBT commun...   1724.0
# 90   583  We speak for all fellow members of LGBT commun...    186.0
# 91   584  We speak for all fellow members of LGBT commun...   3206.0
# 92   653  THE COLORFUL ACTIVISM OF NEW YORK'S MOST RADIC...     25.0
# 93   654  NOM'S LAST ATTEMPT TO BAN SAME SEX MARRIAGE Na...     49.0
# 94   656  RUBY ROSE SHARING THOUGHTS ABOUT GENDER FLUIDI...    150.0
# 95   657  Pete Buttigieg is South Bend's 32nd mayor and ...      1.0
# 96   658  The ninth transgender was found death in the U...     80.0
# 97   659  Matt Cage comes out as gay       The pro wrest...      0.0
# 98   660  First LGBT studies course opens in a San Franc...      3.0
# 99   661  Good morning, dear friends! Have a tasty and c...     12.0
#
#     Impressions       Age              CreationDate  \
# 0         137.0  18 - 65+  06/10/15 02:59:53 AM PDT
# 1         452.0  18 - 65+  06/23/15 07:04:01 AM PDT
# 2         374.0  18 - 65+  06/23/15 07:02:40 AM PDT
# 3          31.0  18 - 65+  06/09/15 03:50:21 AM PDT
# 4         326.0  18 - 65+  06/10/15 07:34:52 AM PDT
# 5        1478.0  18 - 65+  06/12/15 03:13:16 AM PDT
# 6         125.0  18 - 65+  06/11/15 06:51:30 AM PDT
# 7         168.0  18 - 65+  06/11/15 07:03:58 AM PDT
# 8         482.0  18 - 65+  06/15/15 07:21:33 AM PDT
# 9         524.0  18 - 65+  06/15/15 07:22:00 AM PDT
# 10        764.0  18 - 65+  06/15/15 07:21:47 AM PDT
# 11        676.0  18 - 65+  06/15/15 07:22:20 AM PDT
# 12       1075.0  18 - 65+  06/16/15 07:36:57 AM PDT
# 13        153.0  18 - 65+  06/16/15 07:37:14 AM PDT
# 14        476.0  18 - 65+  06/16/15 08:20:31 AM PDT
# 15        745.0  18 - 65+  06/17/15 07:41:34 AM PDT
# 16        746.0  18 - 65+  06/17/15 07:41:07 AM PDT
# 17       1290.0  18 - 65+  06/17/15 07:41:46 AM PDT
# 18       1005.0  18 - 65+  06/17/15 07:42:02 AM PDT
# 19        844.0  18 - 65+  06/17/15 07:45:33 AM PDT
# 20       5072.0  18 - 65+  06/18/15 04:36:59 AM PDT
# 21        866.0  18 - 65+  06/18/15 02:50:25 AM PDT
# 22        441.0  18 - 65+  06/18/15 07:21:41 AM PDT
# 23        708.0  18 - 65+  06/23/15 07:41:01 AM PDT
# 24        759.0  18 - 65+  06/23/15 07:41:21 AM PDT
# 16  United States: Baltimore Maryland; Ferguson, S...  unavailable     175.31
# 17  United States: Baltimore Maryland; Ferguson, S...  unavailable     270.36
# 18  United States: Baltimore Maryland; Ferguson, S...  unavailable     248.56
# 19  United States: Baltimore Maryland; Ferguson, S...  unavailable     169.47
# 20  United States: Baltimore Maryland; Ferguson, S...  unavailable    1295.48
# 21  United States: Baltimore Maryland: Ferguson, S...  unavailable     199.94
# 22  United States: Baltimore Maryland; Ferguson, S...  unavailable      91.73
# 23  United States: Baltimore Maryland: Ferguson, S...  unavailable     173.92
# 24  United States: Baltimore Maryland; Ferguson, S...  unavailable     258.89
# 25  United States: Baltimore Maryland: Ferguson, S...  unavailable     174.35
# 26  United States: Baltimore Maryland; Ferguson, S...  unavailable     174.26
# 27  United States: Baltimore Maryland: Ferguson, S...  unavailable     174.02
# 28  United States: Baltimore Maryland; Ferguson, S...  unavailable     174.75
# 29                                      United States        mixed      18.10
# ..                                                ...          ...        ...
# 70  United States: Baltimore Maryland; Ferguson, S...  unavailable       0.00
# 71                                      United States   right wing     798.92
# 72                                      United States   right wing       0.00
# 73                                      United States   right wing  331675.75
# 74                                      United States   right wing       0.00
# 75                                      United States   right wing       0.00
# 76                                      United States   right wing       0.00
# 77                                      United States   right wing       0.00
# 78                                      United States   right wing     434.53
# 79                                      United States   right wing       0.00
# 80                                      United States   right wing       0.00
# 81                                      United States   right wing       0.00
# 82                                      United States   right wing       0.00
# 83                                      United States   right wing       0.00
# 84                                      United States   right wing       0.00
# 85                                      United States   right wing       0.00
# 86                                      United States   right wing       0.00
# 87                                      United States         lgbt     129.66
# 88                                      United States         lgbt    1362.57
# 89                                      United States         lgbt   10085.77
# 90                                      United States         lgbt    1393.55
# 91                                      United States         lgbt   16630.20
# 92                           Living In: United States  unavailable     179.89
# 93                           Living In: United States  unavailable     183.93
# 94                           Living In: United States  unavailable     368.34
# 95                           Living In: United States  unavailable       9.15
# 96                           Living In: United States  unavailable     181.49
# 97                           Living In: United States  unavailable       0.00
# 98                           Living In: United States  unavailable      42.94
# 99                           Living In: United States  unavailable      53.13
#
#    AdSpendCurrency
# 0              RUB
# 1              RUB
# 2              RUB
# 3              RUB
# 4              RUB
# 5              RUB
# 6              RUB
# 7              RUB
# 8              RUB
# 9              RUB
# 10             RUB
# 11             RUB
# 12             RUB
# 13             RUB
# 14             RUB
# 15             RUB
# 16             RUB
# 17             RUB
# 18             RUB
# 19             RUB
# 20             RUB
# 21             RUB
# 22             RUB
# 23             RUB
# 24             RUB
# 25             RUB
# 26             RUB
# 27             RUB
# 28             RUB
# 29             RUB
# ..             ...
# 70     unavailable
# 71             RUB
# 72     unavailable
# 73             RUB
# 74     unavailable
# 75     unavailable
# 76     unavailable
# 77     unavailable
# 78             RUB
# 79     unavailable
# 80     unavailable
# 81     unavailable
# 82     unavailable
# 83     unavailable
# 84     unavailable
# 85     unavailable
# 86     unavailable
# 87             RUB
# 88             RUB
# 89             RUB
# 90             RUB
# 91             RUB
# 92             RUB
# 93             RUB
# 94             RUB
# 95             RUB
# 96             RUB
# 97     unavailable
# 98             RUB
# 99             RUB
#
# [100 rows x 11 columns]
